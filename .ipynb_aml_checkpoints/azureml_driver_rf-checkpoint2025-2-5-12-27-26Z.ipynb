# %%
# Handle to the workspace
from azure.ai.ml import MLClient

# Authentication package
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()

# Get a handle to the workspace. You can find the info on the workspace tab on ml.azure.com
ml_client = MLClient(
    credential=credential,
    subscription_id="08539d0e-620d-424c-aea8-56853ed8fe3e",
    resource_group_name="dspro2",
    workspace_name="dspro2ml",
)

# %%
# import the libraries
from azure.ai.ml import command
from azure.ai.ml import Input

# name the model you registered earlier in the training script
experiment_name = "bostonhousing"
registered_model_name = "bostonhousing_rf"
registered_data_name = "bostonhousing_gold"

# configure the command job
job = command(
    inputs=dict(
        # uri_file refers to a specific file as a data asset
        data=registered_data_name,
        test_train_ratio=0.2,  # input variable in main.py
        registered_model_name=registered_model_name,  # input variable in main.py
        n_estimators = 100,
    ),
    code="./src/",  # location of source code
    # The inputs/outputs are accessible in the command via the ${{ ... }} notation
    command="python main_rf.py --data ${{inputs.data}} --test_train_ratio ${{inputs.test_train_ratio}} --registered_model_name ${{inputs.registered_model_name}} --n_estimators ${{inputs.n_estimators}}",
    # This is the ready-made environment you are using
    environment="azureml://registries/azureml/environments/sklearn-1.5/labels/latest",
    #environment="azureml://registries/azureml/environments/ai-ml-automl/versions/18",
    # This is the compute you created earlier. You can alternatively remove this line to use serverless compute to run the job
    compute="curdon-cpu",
    # An experiment is a container for all the iterations one does on a certain project. All the jobs submitted under the same experiment name would be listed next to each other in Azure ML studio.
    experiment_name=experiment_name,
)

# %%
ml_client.create_or_update(job)
# Out:
# Uploading src (0.0 MBs): 100%|██████████| 3814/3814 [00:00<00:00, 39704.43it/s]
# Command({'parameters': {}, 'init': False, 'name': 'bold_prune_w0sclxj716', 'type': 'command', 'status': 'Starting', 'log_files': None, 'description': None, 'tags': {}, 'properties': {'mlflow.source.git.repoURL': 'git@github.com:curdon/dspro2.git', 'mlflow.source.git.branch': 'notebook', 'mlflow.source.git.commit': '3dcfb53b07cb4920efbc3c059120a9741da974a7', 'azureml.git.dirty': 'True', '_azureml.ComputeTargetType': 'amlcdsi', '_azureml.ClusterName': 'curdon-cpu', 'ContentSnapshotId': '941007e4-5c75-4f20-8e1e-e54df7813a02'}, 'print_as_yaml': False, 'id': '/subscriptions/08539d0e-620d-424c-aea8-56853ed8fe3e/resourceGroups/dspro2/providers/Microsoft.MachineLearningServices/workspaces/dspro2ml/jobs/bold_prune_w0sclxj716', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/curdon-cpu/code/Users/curdin.derungs/dspro2', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7fb0c00fd1e0>, 'serialize': <msrest.serialization.Serializer object at 0x7fb0c00fe7a0>, 'allowed_keys': {}, 'key_restriction': False, 'logger': <TraceLogger attr_dict (WARNING)>, 'display_name': 'bold_prune_w0sclxj716', 'experiment_name': 'bostonhousing', 'compute': 'curdon-cpu', 'services': {'Tracking': {'endpoint': 'azureml://switzerlandnorth.api.azureml.ms/mlflow/v1.0/subscriptions/08539d0e-620d-424c-aea8-56853ed8fe3e/resourceGroups/dspro2/providers/Microsoft.MachineLearningServices/workspaces/dspro2ml?', 'type': 'Tracking'}, 'Studio': {'endpoint': 'https://ml.azure.com/runs/bold_prune_w0sclxj716?wsid=/subscriptions/08539d0e-620d-424c-aea8-56853ed8fe3e/resourcegroups/dspro2/workspaces/dspro2ml&tid=4cab7802-df28-4dd1-9b11-828cb2edad18', 'type': 'Studio'}}, 'comment': None, 'job_inputs': {'data': 'bostonhousing_gold', 'test_train_ratio': '0.2', 'learning_rate': '0.25', 'registered_model_name': 'bostonhousing_rf'}, 'job_outputs': {'default': {'type': 'uri_folder', 'path': 'azureml://datastores/workspaceartifactstore/ExperimentRun/dcid.bold_prune_w0sclxj716', 'mode': 'rw_mount'}}, 'inputs': {'data': <azure.ai.ml.entities._job.pipeline._io.base.NodeInput object at 0x7fb0c00fe0e0>, 'test_train_ratio': <azure.ai.ml.entities._job.pipeline._io.base.NodeInput object at 0x7fb0c00fd5a0>, 'learning_rate': <azure.ai.ml.entities._job.pipeline._io.base.NodeInput object at 0x7fb0c00fd150>, 'registered_model_name': <azure.ai.ml.entities._job.pipeline._io.base.NodeInput object at 0x7fb0c00fcc10>}, 'outputs': {'default': <azure.ai.ml.entities._job.pipeline._io.base.NodeOutput object at 0x7fb0c00fdd20>}, 'component': CommandComponent({'latest_version': None, 'intellectual_property': None, 'auto_increment_version': True, 'source': 'REMOTE.WORKSPACE.JOB', 'is_anonymous': False, 'auto_delete_setting': None, 'name': 'bold_prune_w0sclxj716', 'description': None, 'tags': {}, 'properties': {}, 'print_as_yaml': False, 'id': None, 'Resource__source_path': None, 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/curdon-cpu/code/Users/curdin.derungs/dspro2', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7fb0c00fd1e0>, 'serialize': <msrest.serialization.Serializer object at 0x7fb0c00fdff0>, 'command': 'python main_rf.py --data ${{inputs.data}} --test_train_ratio ${{inputs.test_train_ratio}} --learning_rate ${{inputs.learning_rate}} --registered_model_name ${{inputs.registered_model_name}}', 'code': '/subscriptions/08539d0e-620d-424c-aea8-56853ed8fe3e/resourceGroups/dspro2/providers/Microsoft.MachineLearningServices/workspaces/dspro2ml/codes/26726f92-6cde-4513-b60c-ff42b4dc6413/versions/1', 'environment_variables': {}, 'environment': 'azureml://registries/azureml/environments/sklearn-1.5/labels/latest', 'distribution': None, 'resources': None, 'queue_settings': None, 'version': None, 'schema': None, 'type': 'command', 'display_name': 'bold_prune_w0sclxj716', 'is_deterministic': True, 'inputs': {'data': {'type': 'string', 'default': 'bostonhousing_gold'}, 'test_train_ratio': {'type': 'string ...
